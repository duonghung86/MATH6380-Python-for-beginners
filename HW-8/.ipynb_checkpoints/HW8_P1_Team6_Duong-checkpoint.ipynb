# %% [markdown]
# ## You are hired by City of Houston to analyze presence of E.coli bacteria in the city’s waterways.
#
# You are asked to preform data analysis to accomplish three specific goals:
#
# 1.	Compute average amount of E.coli per year in Houston waterways. Plot a bar graph in which x-axis is years (2013-2016) and y-axis is E.coli amount. [25 points]
# 2.	Compute average amount of E.coli per month in Houston waterways. Plot a bar graph in which x-axis is months (Jan-Dec) and y-axis is E.coli amount. Each month is aggregated over the years. [25 points]
# 3.	Show correlations between E.coli and chemical factors such as water PH level, dissolved oxygen, specific conductance, etc. [50 points]

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Import data set
df=pd.read_excel('Ecoli Data.xlsx')
print(df.shape)
print(df.columns)
df.head()
# Out:
# (3565, 34)
# Index(['Sample ID', 'Station ID', 'Date Collected', 'Water Temp',
#        'Flow Stream', 'Transparency', 'Specific Conductance',
#        'Dissolved Oxygen', 'PH', 'Salinity', 'Residue', 'Ammonia Nitrogen',
#        'Nitrate Nitrogen', 'Nitrogen', 'Phosphorous', 'Chloride', 'Sulfate',
#        'Flow Severity', 'E.coli', 'Entercocci', 'E.coli Holding Time',
#        'Days Since Precipitation', 'Water Depth', 'Water Flow',
#        'Wind Intensity', 'Present Weather', 'Water Surface', 'Water Color',
#        'Water Odor', 'Tide', 'Primary Contact', 'Evidence of Recreation',
#        'Sample Depth', 'Field Temp'],
#       dtype='object')
#    Sample ID  Station ID Date Collected  Water Temp  Flow Stream  \
# 0          1           1     2013-10-02        26.7          NaN
# 1          2           1     2013-11-26         9.3          NaN
# 2          3           1     2014-01-30         8.2          NaN
# 3          4           1     2014-02-25        18.9          NaN
# 4          5           1     2014-03-24        16.3          NaN
#
#    Transparency  Specific Conductance  Dissolved Oxygen   PH  Salinity  ...  \
# 0          0.30                 341.0               4.2  7.6       NaN  ...
# 1          0.19                 228.0              10.2  7.6       NaN  ...
# 2          0.85                 692.0              15.1  8.2       NaN  ...
# 3          0.14                 710.0               7.0  7.7       NaN  ...
# 4          1.20                 734.0               9.3  7.9       NaN  ...
#
#    Wind Intensity  Present Weather  Water Surface  Water Color  Water Odor  \
# 0             2.0              4.0            2.0          3.0         6.0
# 1             3.0              3.0            2.0          3.0         6.0
# 2             2.0              3.0            2.0          3.0         6.0
# 3             2.0              3.0            2.0          3.0         6.0
# 4             2.0              3.0            2.0          1.0         6.0
#
#    Tide  Primary Contact  Evidence of Recreation  Sample Depth  Field Temp
# 0   NaN              0.0                     0.0          0.09         NaN
# 1   NaN              0.0                     0.0          0.27         NaN
# 2   NaN              0.0                     0.0          0.12         NaN
# 3   NaN              0.0                     0.0          0.09         NaN
# 4   NaN              0.0                     0.0          0.06         NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ### 1. Compute average amount of E.coli per year in Houston waterways.
#
# Plot a bar graph in which x-axis is years (2013-2016) and y-axis is E.coli amount. [25 points]

# %%
df['Date Collected']=pd.to_datetime(df['Date Collected']) # convert date collected to datetime object
sbs_df=df['E.coli']
df['Year']=[x.year for x in df['Date Collected']]
df['Month']=[x.month for x in df['Date Collected']]
df['Day']=[x.day for x in df['Date Collected']]
year_list=df['Year'].unique()
aepy=[] # Average amount of E.coli Per Year
for i in range(2013,2017):
    ecoli_py=df['E.coli'][df['Year']==i]
    aepy.append(ecoli_py.mean())
plt.bar(year_list,aepy)
plt.xticks(year_list)
plt.ylabel('Average amount of E.coli')
plt.title('Average amount of E.coli per year in Houston waterways')

plt.show()

# %% [markdown]
# ## 2. Compute average amount of E.coli per month in Houston waterways.
#
# Plot a bar graph in which x-axis is months (Jan-Dec) and y-axis is E.coli amount. Each month is aggregated over the years. [25 points]

# %%
month_list=df['Month'].unique()
aepm=[] # Average amount of E.coli Per Month
for i in month_list:
    ecoli_pm=df['E.coli'][df['Month']==i]
    aepm.append(ecoli_pm.mean())
plt.bar(month_list,aepm)
plt.xticks(month_list)
plt.ylabel('Average amount of E.coli')
plt.title('Average amount of E.coli per month in Houston waterways')

plt.show()

# %%
feature_list=df.columns
for feat in feature_list:
    if df[feat].isnull().any():
        noma=df[feat].isnull().value_counts()
        noma=noma[1]
        mp=round(noma/35.65,4) # Missing values percentage
        print(feat +" : " + str(noma) + " → Percentage = " + str(mp))
        #Drop all feature that have percentage of missing values larger than 80%
        if mp>80: df.drop(columns=[feat],inplace=True)
        #Fillna by mean for features that have percentage of missing values smaller than 2%
        if mp<2 : df[feat].fillna(df[feat].mean(),inplace=True)
print(df.shape)
df['E.coli Holding Time'].fillna(8,inplace=True)
df.head()
chemicals_list=['Water Temp',
       'Transparency', 'Specific Conductance', 'Dissolved Oxygen', 'PH',
       'Residue', 'Ammonia Nitrogen', 'Nitrate Nitrogen', 'Nitrogen',
       'Phosphorous', 'Chloride', 'Sulfate', 'Flow Severity','E.coli', 
       'Entercocci', 'E.coli Holding Time', 'Days Since Precipitation',
       'Water Depth', 'Wind Intensity', 'Present Weather', 'Water Surface',
       'Water Color', 'Water Odor', 'Primary Contact',
       'Evidence of Recreation', 'Sample Depth']
# Out:
# Water Temp : 11 → Percentage = 0.3086
# Flow Stream : 3008 → Percentage = 84.3759
# Transparency : 25 → Percentage = 0.7013
# Specific Conductance : 15 → Percentage = 0.4208
# Dissolved Oxygen : 61 → Percentage = 1.7111
# PH : 40 → Percentage = 1.122
# Salinity : 3157 → Percentage = 88.5554
# Residue : 13 → Percentage = 0.3647
# Ammonia Nitrogen : 12 → Percentage = 0.3366
# Nitrate Nitrogen : 6 → Percentage = 0.1683
# Nitrogen : 1972 → Percentage = 55.3156
# Phosphorous : 11 → Percentage = 0.3086
# Chloride : 12 → Percentage = 0.3366
# Sulfate : 9 → Percentage = 0.2525
# Flow Severity : 422 → Percentage = 11.8373
# E.coli : 345 → Percentage = 9.6774
# Entercocci : 1818 → Percentage = 50.9958
# E.coli Holding Time : 345 → Percentage = 9.6774
# Days Since Precipitation : 6 → Percentage = 0.1683
# Water Depth : 14 → Percentage = 0.3927
# Water Flow : 3008 → Percentage = 84.3759
# Wind Intensity : 6 → Percentage = 0.1683
# Present Weather : 6 → Percentage = 0.1683
# Water Surface : 12 → Percentage = 0.3366
# Water Color : 12 → Percentage = 0.3366
# Water Odor : 12 → Percentage = 0.3366
# Tide : 3260 → Percentage = 91.4446
# Primary Contact : 7 → Percentage = 0.1964
# Evidence of Recreation : 7 → Percentage = 0.1964
# Field Temp : 3565 → Percentage = 100.0
# (3565, 32)

# %%
df1=df[chemicals_list]
df1.corr()
# Out:
#                           Water Temp  Transparency  Specific Conductance  \
# Water Temp                  1.000000     -0.071395              0.009749
# Transparency               -0.071395      1.000000              0.081086
# Specific Conductance        0.009749      0.081086              1.000000
# Dissolved Oxygen           -0.232618      0.144200             -0.023908
# PH                          0.135012      0.118419              0.023713
# Residue                     0.062687     -0.226427             -0.061180
# Ammonia Nitrogen            0.027151     -0.020439              0.046102
# Nitrate Nitrogen           -0.044791     -0.021157              0.102969
# Nitrogen                    0.181684     -0.084091              0.018471
# Phosphorous                 0.052174     -0.043092              0.098670
# Chloride                    0.004838      0.027751              0.917780
# Sulfate                     0.008728      0.159403              0.883426
# Flow Severity              -0.058170     -0.334279             -0.466942
# E.coli                      0.024984     -0.090313             -0.086330
# Entercocci                 -0.102626     -0.186976             -0.102688
# E.coli Holding Time              NaN           NaN                   NaN
# Days Since Precipitation    0.058856      0.203433              0.171233
# Water Depth                 0.013249     -0.190097              0.246364
# Wind Intensity             -0.210327      0.035235              0.033666
# Present Weather            -0.027481      0.010361             -0.018413
# Water Surface              -0.108242     -0.115934              0.012444
# Water Color                 0.035594      0.479709              0.146210
# Water Odor                 -0.011887      0.014764              0.001221
# Primary Contact            -0.007854     -0.001487             -0.001429
# Evidence of Recreation      0.004047     -0.014910              0.006851
# Sample Depth               -0.058983     -0.295696              0.034519
#
#                           Dissolved Oxygen        PH   Residue  \
# Water Temp                       -0.232618  0.135012  0.062687
# Transparency                      0.144200  0.118419 -0.226427
# Specific Conductance             -0.023908  0.023713 -0.061180
# Dissolved Oxygen                  1.000000  0.675543  0.006736
# PH                                0.675543  1.000000  0.001189
# Residue                           0.006736  0.001189  1.000000
# Ammonia Nitrogen                 -0.071689 -0.041993  0.003916
# Nitrate Nitrogen                  0.173557  0.179740 -0.062945
# Nitrogen                         -0.061276  0.017525  0.084177
# Phosphorous                       0.086524  0.134128 -0.049114
# Chloride                         -0.019078  0.011535 -0.028302
# Sulfate                           0.048405  0.099400 -0.067696
# Flow Severity                    -0.092529 -0.216793  0.101851
# E.coli                           -0.100907 -0.061798  0.034043
# Entercocci                       -0.071195 -0.119488  0.074187
# E.coli Holding Time                    NaN       NaN       NaN
# Days Since Precipitation          0.085686  0.184371 -0.023343
# Water Depth                      -0.199340 -0.227954  0.022251
# Wind Intensity                    0.165054  0.090465 -0.025977
# Present Weather                  -0.079688 -0.064344  0.035436
# Water Surface                     0.136527  0.022401  0.020107
# Water Color                       0.148353  0.243848 -0.114955
# Water Odor                        0.132401  0.077444  0.013964
# Primary Contact                  -0.010291 -0.005686 -0.008570
# Evidence of Recreation           -0.017541  0.000056 -0.010056
# Sample Depth                     -0.317772 -0.299636 -0.006330
#
#                           Ammonia Nitrogen  Nitrate Nitrogen  Nitrogen  \
# Water Temp                        0.027151         -0.044791  0.181684
# Transparency                     -0.020439         -0.021157 -0.084091
# Specific Conductance              0.046102          0.102969  0.018471
# Dissolved Oxygen                 -0.071689          0.173557 -0.061276
# PH                               -0.041993          0.179740  0.017525
# Residue                           0.003916         -0.062945  0.084177
# Ammonia Nitrogen                  1.000000         -0.028674  0.078854
# Nitrate Nitrogen                 -0.028674          1.000000  0.021826
# Nitrogen                          0.078854          0.021826  1.000000
# Phosphorous                       0.154070          0.852646  0.111724
# Chloride                          0.011524          0.063477  0.027949
# Sulfate                           0.013008          0.122683  0.022366
# Flow Severity                    -0.020385         -0.246645 -0.035494
# E.coli                            0.271238         -0.129194  0.207655
# Entercocci                        0.033181         -0.170636  0.096854
# E.coli Holding Time                    NaN               NaN       NaN
# Days Since Precipitation          0.023269          0.323525  0.001982
# Water Depth                      -0.008336         -0.069050  0.036569
# Wind Intensity                    0.000959          0.081533  0.014725
# Present Weather                   0.004483         -0.013808  0.036729
# Water Surface                    -0.005814          0.113885  0.012156
# Water Color                       0.031910          0.211297 -0.043480
# Water Odor                       -0.204405          0.063549 -0.221482
# Primary Contact                  -0.001894         -0.006162  0.012216
# Evidence of Recreation           -0.003240         -0.006521  0.005417
# Sample Depth                      0.008523          0.093738  0.033628
#
#                           Phosphorous  ...  Days Since Precipitation  \
# Water Temp                   0.052174  ...                  0.058856
# Transparency                -0.043092  ...                  0.203433
# Specific Conductance         0.098670  ...                  0.171233
# Dissolved Oxygen             0.086524  ...                  0.085686
# PH                           0.134128  ...                  0.184371
# Residue                     -0.049114  ...                 -0.023343
# Ammonia Nitrogen             0.154070  ...                  0.023269
# Nitrate Nitrogen             0.852646  ...                  0.323525
# Nitrogen                     0.111724  ...                  0.001982
# Phosphorous                  1.000000  ...                  0.316923
# Chloride                     0.057046  ...                  0.099270
# Sulfate                      0.093111  ...                  0.209043
# Flow Severity               -0.213713  ...                 -0.381265
# E.coli                      -0.060460  ...                 -0.129015
# Entercocci                  -0.112122  ...                 -0.219183
# E.coli Holding Time               NaN  ...                       NaN
# Days Since Precipitation     0.316923  ...                  1.000000
# Water Depth                 -0.088828  ...                 -0.128837
# Wind Intensity               0.050018  ...                  0.093940
# Present Weather             -0.003229  ...                 -0.110102
# Water Surface                0.088171  ...                 -0.022371
# Water Color                  0.177262  ...                  0.301754
# Water Odor                   0.009945  ...                  0.004876
# Primary Contact             -0.006450  ...                 -0.036239
# Evidence of Recreation      -0.001585  ...                 -0.028376
# Sample Depth                 0.075446  ...                 -0.129263
#
#                           Water Depth  Wind Intensity  Present Weather  \
# Water Temp                   0.013249       -0.210327        -0.027481
# Transparency                -0.190097        0.035235         0.010361
# Specific Conductance         0.246364        0.033666        -0.018413
# Dissolved Oxygen            -0.199340        0.165054        -0.079688
# PH                          -0.227954        0.090465        -0.064344
# Residue                      0.022251       -0.025977         0.035436
# Ammonia Nitrogen            -0.008336        0.000959         0.004483
# Nitrate Nitrogen            -0.069050        0.081533        -0.013808
# Nitrogen                     0.036569        0.014725         0.036729
# Phosphorous                 -0.088828        0.050018        -0.003229
# Chloride                     0.286137        0.027234        -0.015401
# Sulfate                      0.204324        0.057717        -0.022714
# Flow Severity                0.326796       -0.009660         0.074845
# E.coli                       0.060969       -0.043378         0.083845
# Entercocci                   0.066513       -0.034167         0.198987
# E.coli Holding Time               NaN             NaN              NaN
# Days Since Precipitation    -0.128837        0.093940        -0.110102
# Water Depth                  1.000000       -0.043365        -0.004065
# Wind Intensity              -0.043365        1.000000         0.003413
# Present Weather             -0.004065        0.003413         1.000000
# Water Surface                0.040840        0.168067         0.064711
# Water Color                 -0.125759        0.076035        -0.052594
# Water Odor                   0.021637        0.017481        -0.007017
# Primary Contact              0.053243       -0.007647         0.031390
# Evidence of Recreation       0.055957       -0.000978         0.003650
# Sample Depth                 0.426100       -0.009349         0.019262
#
#                           Water Surface  Water Color  Water Odor  \
# Water Temp                    -0.108242     0.035594   -0.011887
# Transparency                  -0.115934     0.479709    0.014764
# Specific Conductance           0.012444     0.146210    0.001221
# Dissolved Oxygen               0.136527     0.148353    0.132401
# PH                             0.022401     0.243848    0.077444
# Residue                        0.020107    -0.114955    0.013964
# Ammonia Nitrogen              -0.005814     0.031910   -0.204405
# Nitrate Nitrogen               0.113885     0.211297    0.063549
# Nitrogen                       0.012156    -0.043480   -0.221482
# Phosphorous                    0.088171     0.177262    0.009945
# Chloride                       0.013753     0.087752    0.016642
# Sulfate                        0.014858     0.203936   -0.006958
# Flow Severity                  0.079951    -0.340269   -0.001586
# E.coli                        -0.048742    -0.066349   -0.202739
# Entercocci                    -0.005968    -0.211173   -0.120352
# E.coli Holding Time                 NaN          NaN         NaN
# Days Since Precipitation      -0.022371     0.301754    0.004876
# Water Depth                    0.040840    -0.125759    0.021637
# Wind Intensity                 0.168067     0.076035    0.017481
# Present Weather                0.064711    -0.052594   -0.007017
# Water Surface                  1.000000    -0.084053   -0.023889
# Water Color                   -0.084053     1.000000   -0.030887
# Water Odor                    -0.023889    -0.030887    1.000000
# Primary Contact                0.006694     0.015294    0.006786
# Evidence of Recreation         0.003978     0.018383    0.007195
# Sample Depth                   0.012833    -0.159248    0.005072
#
#                           Primary Contact  Evidence of Recreation  \
# Water Temp                      -0.007854                0.004047
# Transparency                    -0.001487               -0.014910
# Specific Conductance            -0.001429                0.006851
# Dissolved Oxygen                -0.010291               -0.017541
# PH                              -0.005686                0.000056
# Residue                         -0.008570               -0.010056
# Ammonia Nitrogen                -0.001894               -0.003240
# Nitrate Nitrogen                -0.006162               -0.006521
# Nitrogen                         0.012216                0.005417
# Phosphorous                     -0.006450               -0.001585
# Chloride                         0.000450                0.011041
# Sulfate                         -0.001006                0.001151
# Flow Severity                   -0.034411               -0.021720
# E.coli                           0.008081                0.025471
# Entercocci                      -0.012467               -0.019287
# E.coli Holding Time                   NaN                     NaN
# Days Since Precipitation        -0.036239               -0.028376
# Water Depth                      0.053243                0.055957
# Wind Intensity                  -0.007647               -0.000978
# Present Weather                  0.031390                0.003650
# Water Surface                    0.006694                0.003978
# Water Color                      0.015294                0.018383
# Water Odor                       0.006786                0.007195
# Primary Contact                  1.000000                0.785745
# Evidence of Recreation           0.785745                1.000000
# Sample Depth                     0.003147                0.019258
#
#                           Sample Depth
# Water Temp                   -0.058983
# Transparency                 -0.295696
# Specific Conductance          0.034519
# Dissolved Oxygen             -0.317772
# PH                           -0.299636
# Residue                      -0.006330
# Ammonia Nitrogen              0.008523
# Nitrate Nitrogen              0.093738
# Nitrogen                      0.033628
# Phosphorous                   0.075446
# Chloride                      0.071112
# Sulfate                      -0.017100
# Flow Severity                 0.256071
# E.coli                        0.051753
# Entercocci                    0.084866
# E.coli Holding Time                NaN
# Days Since Precipitation     -0.129263
# Water Depth                   0.426100
# Wind Intensity               -0.009349
# Present Weather               0.019262
# Water Surface                 0.012833
# Water Color                  -0.159248
# Water Odor                    0.005072
# Primary Contact               0.003147
# Evidence of Recreation        0.019258
# Sample Depth                  1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# ## 3. Show correlations between E.coli and chemical factors such as water PH level, dissolved oxygen, specific conductance, etc.

# %%
chemicals_list.remove('E.coli Holding Time')
df2=df[chemicals_list]
corrmat = df2.corr()['E.coli'] 
corrmat
# Out:
# Water Temp                  0.024984
# Transparency               -0.090313
# Specific Conductance       -0.086330
# Dissolved Oxygen           -0.100907
# PH                         -0.061798
# Residue                     0.034043
# Ammonia Nitrogen            0.271238
# Nitrate Nitrogen           -0.129194
# Nitrogen                    0.207655
# Phosphorous                -0.060460
# Chloride                   -0.120361
# Sulfate                    -0.082461
# Flow Severity               0.184179
# E.coli                      1.000000
# Entercocci                  0.540979
# Days Since Precipitation   -0.129015
# Water Depth                 0.060969
# Wind Intensity             -0.043378
# Present Weather             0.083845
# Water Surface              -0.048742
# Water Color                -0.066349
# Water Odor                 -0.202739
# Primary Contact             0.008081
# Evidence of Recreation      0.025471
# Sample Depth                0.051753
# Name: E.coli, dtype: float64
