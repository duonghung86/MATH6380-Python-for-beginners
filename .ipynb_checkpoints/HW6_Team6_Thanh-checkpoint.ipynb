# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
#Import data sets
#fil_nam=os.listdir("data") # name of all files in the folder data in the current working directory
tra_set = pd.read_excel(r'titanic_traning.xlsx')
tes_set = pd.read_excel(r'titanic_test.xlsx')

#Show the head of data
print("Train set's head: \n",tra_set.head())
print("Test set's head: \n",tes_set.head())
# Out:
# Train set's head:
#     ID  pclass  gender   age  sibsp  parch  fare embarked  survived
# 0   1       3    male  20.0      0      0   4.0        C         0
# 1   2       3  female  18.0      0      0   7.2        C         1
# 2   3       2    male   NaN      0      0  15.6        C         0
# 3   4       2    male   NaN      0      0   0.0        S         0
# 4   5       3  female   2.0      3      2  27.9        S         0
# Test set's head:
#      ID  pclass  gender   age  sibsp  parch   fare embarked
# 0  917       1  female  29.0      0      0  211.3        S
# 1  918       1  female  25.0      1      2  151.6        S
# 2  919       1  female  63.0      1      0   78.0        S
# 3  920       1    male  39.0      0      0    0.0        S
# 4  921       1  female  53.0      2      0   51.5        S

# %% [markdown]
# ### Understand the data

# %%
# Check basic information of the feature
def bas_inf(feat):
    print(feat.head())
    print(len(feat)) #length of data
    #See unique values
    print(pd.unique(feat))
    # Display histogram of feature
    feat.value_counts().plot('bar')
    #check whether there is missing data
    if np.any(feat.isnull())==False:
        if feat.dtypes !='O':
            print(np.mean(feat))
            print(np.std(feat))
            print(np.median(feat))

# %%
bas_inf(tra_set['sibsp'])
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    3
# Name: sibsp, dtype: int64
# 916
# [0 3 1 2 5 8 4]
# 0.5218340611353712
# 1.0981143617600069
# 0.0

# %% [markdown]
# #### Fill the missing data

# %%
tra_set=tra_set.fillna(method='ffill')

# %% [markdown]
# ### Algorithm OneR function

# %%
def oneR(fea_nam):
    # Use the loop to apply algorithm on each type of features
    for typ in tra_set[fea_nam].unique():
        sss=tra_set['survived'][tra_set[fea_nam]==typ] # subset of survived status of this type
        vc=sss.value_counts()
        #print(vc)
        print('If',fea_nam,' is ', typ,',the number of survived in train set is',vc[1])
        maj=np.argmax(vc) # find the majority survived status
        print('The majority survived status is',maj)
        #Assign the majority status onto this type of test set
        tes_set['survived'][tes_set[fea_nam]==typ]=maj
    #print(tes_set['survived'])
    ws_nam=fea_nam+'_Based_Prediction'
    tes_set['survived'].to_excel(pre_fn,sheet_name=ws_nam,index=False,header=False,startcol=2,startrow=1,engine='openpyxl')

# %%
tes_set['survived']=np.nan
pre_fn='titanic_test_predictions.xlsx'
oneR('pclass')
writer=pd.ExcelWriter(pre_fn)
tes_set['survived'].to_excel(writer,sheet_name=ws_nam,index=False,header=False,startcol=2,startrow=1,engine='openpyxl')
# Out:
# If pclass  is  3 ,the number of survived in train set is 128
# The majority survived status is 0
# If pclass  is  2 ,the number of survived in train set is 89
# The majority survived status is 0
# C:\Users\Duong Hung\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# If pclass  is  1 ,the number of survived in train set is 136
# The majority survived status is 1

# %%
'gender'+'_based'
# Out:
# 'gender_based'

# %%
tra_set['gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
tes_set
# Out:
#        ID  pclass  gender   age  sibsp  parch   fare embarked  survived
# 0     917       1  female  29.0      0      0  211.3        S       1.0
# 1     918       1  female  25.0      1      2  151.6        S       1.0
# 2     919       1  female  63.0      1      0   78.0        S       1.0
# 3     920       1    male  39.0      0      0    0.0        S       1.0
# 4     921       1  female  53.0      2      0   51.5        S       1.0
# 5     922       1    male  71.0      0      0   49.5        C       1.0
# 6     923       1  female  24.0      0      0   69.3        C       1.0
# 7     924       1  female  50.0      0      1  247.5        C       1.0
# 8     925       1  female  32.0      0      0   76.3        C       1.0
# 9     926       1    male  26.0      0      0   30.0        C       1.0
# 10    927       1    male  25.0      0      0   26.0        C       1.0
# 11    928       1  female  30.0      0      0  164.9        S       1.0
# 12    929       1    male   NaN      0      0   26.6        S       1.0
# 13    930       1    male  45.0      0      0   26.6        S       1.0
# 14    931       1    male  33.0      0      0    5.0        S       1.0
# 15    932       1    male  11.0      1      2  120.0        S       1.0
# 16    933       1  female   NaN      0      0   27.7        C       1.0
# 17    934       1  female  47.0      1      0   61.2        S       1.0
# 18    935       1    male  27.0      1      0   53.1        S       1.0
# 19    936       1  female  36.0      0      0  262.4        C       1.0
# 20    937       1  female  30.0      0      0   86.5        S       1.0
# 21    938       1  female   NaN      0      1   55.0        S       1.0
# 22    939       1    male  27.0      1      0  136.8        C       1.0
# 23    940       1  female  64.0      0      2   83.2        C       1.0
# 24    941       1    male  27.0      0      0   30.5        S       1.0
# 25    942       1    male  31.0      1      0   57.0        S       1.0
# 26    943       1  female  27.0      1      1  247.5        C       1.0
# 27    944       1  female  48.0      1      0   39.6        C       1.0
# 28    945       1  female  23.0      0      1   83.2        C       1.0
# 29    946       1    male   NaN      0      0  221.8        S       1.0
# ..    ...     ...     ...   ...    ...    ...    ...      ...       ...
# 363  1280       3  female   2.0      0      1   10.5        S       0.0
# 364  1281       3    male  25.0      0      0    7.8        S       0.0
# 365  1282       3    male   NaN      0      0    6.4        C       0.0
# 366  1283       3  female   NaN      1      0   16.1        S       0.0
# 367  1284       3    male  32.0      0      0    7.9        S       0.0
# 368  1285       3    male   NaN      0      0    7.8        Q       0.0
# 369  1286       3    male   NaN      0      0    7.9        S       0.0
# 370  1287       3    male   NaN      0      0    7.2        C       0.0
# 371  1288       3    male  25.0      0      0    0.0        S       0.0
# 372  1289       3  female  18.0      0      0    9.8        S       0.0
# 373  1290       3  female  63.0      0      0    9.6        S       0.0
# 374  1291       3    male  40.5      0      2   14.5        S       0.0
# 375  1292       3  female  10.0      0      2   24.2        S       0.0
# 376  1293       3  female  30.0      1      1   24.2        S       0.0
# 377  1294       3    male   NaN      0      0    9.5        S       0.0
# 378  1295       3    male  33.0      0      0    9.5        S       0.0
# 379  1296       3    male  31.0      3      0   18.0        S       0.0
# 380  1297       3    male  22.0      0      0    7.9        S       0.0
# 381  1298       3  female  38.0      0      0    7.2        C       0.0
# 382  1299       3    male  51.0      0      0    7.8        S       0.0
# 383  1300       3    male  18.0      1      0    6.5        S       0.0
# 384  1301       3    male  21.0      0      0    7.3        S       0.0
# 385  1302       3    male  27.0      0      0    8.7        S       0.0
# 386  1303       3    male  27.0      1      0   14.5        C       0.0
# 387  1304       3    male  45.5      0      0    7.2        C       0.0
# 388  1305       3    male   NaN      0      0   14.5        C       0.0
# 389  1306       3  female  14.5      1      0   14.5        C       0.0
# 390  1307       3  female   NaN      1      0   14.5        C       0.0
# 391  1308       3    male  27.0      0      0    7.2        C       0.0
# 392  1309       3    male  29.0      0      0    7.9        S       0.0
#
# [393 rows x 9 columns]
